# %%
import pandas as pd

# %%
X_train = pd.read_csv("../data/train_features.csv")

# %%
y_train = pd.read_csv("../data/train_df.csv")["target"]

# %%
X_train
# Out:
#        feature_16  feature_9  feature_17  feature_3  feature_2  feature_20  \
# 0             1.0          1         0.0          1          0         1.0
# 1             1.0          0         0.0          1          0         1.0
# 2             1.0          1         0.0          1          0         1.0
# 3             1.0          1         0.0          1          0         1.0
# 4             1.0          1         0.0          1          0         1.0
# ...           ...        ...         ...        ...        ...         ...
# 15076         0.0          1         1.0          0          0         0.0
# 15077         0.0          1         1.0          0          0         0.0
# 15078         0.0          0         1.0          0          0         0.0
# 15079         0.0          1         1.0          0          0         0.0
# 15080         0.0          1         1.0          0          0         0.0
#
# ...
